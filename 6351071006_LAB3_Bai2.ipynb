# %%
STUDENT = 'Đinh Quốc Bảo - 6351071006'

# %% [markdown]
# # Câu a)

# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np

# a) Đọc bộ dữ liệu
print(NAME)
(train_images, train_labels), (test_images, test_labels) = keras.datasets.mnist.load_data()
# Out:
# Đinh Quốc Bảo - 6351071006

# %% [markdown]
# # Câu b)

# %%
print(STUDENT)

print('Kích thước tập train ban đầu:', train_images.shape)
print('Kích thước tập test:', test_images.shape)
print('Số lượng nhãn train:', len(train_labels))
print('Số lượng nhãn test:', len(test_labels))
# Out:
# Đinh Quốc Bảo - 6351071006
# Kích thước tập train ban đầu: (60000, 28, 28)
# Kích thước tập test: (10000, 28, 28)
# Số lượng nhãn train: 60000
# Số lượng nhãn test: 10000

# %% [markdown]
# # Câu c)

# %%
print(STUDENT)
train_images_original = train_images
test_images_original = test_images

train_images = train_images / 255.0
test_images = test_images / 255.0
# Out:
# Đinh Quốc Bảo - 6351071006

# %% [markdown]
# # Câu d)

# %%
from sklearn.model_selection import train_test_split

print(STUDENT)
train_images, validation_images, train_labels, validation_labels = train_test_split(
    train_images, train_labels, test_size=0.2, random_state=42, stratify=train_labels
)

print('Kích thước tập train mới:', train_images.shape)
print('Kích thước tập validation:', validation_images.shape)
print('Số lượng nhãn train mới:', len(train_labels))
print('Số lượng nhãn validation:', len(validation_labels))
# Out:
# Đinh Quốc Bảo - 6351071006
# Kích thước tập train mới: (48000, 28, 28)
# Kích thước tập validation: (12000, 28, 28)
# Số lượng nhãn train mới: 48000
# Số lượng nhãn validation: 12000

# %% [markdown]
# # Câu e)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Dense, Dropout

print(STUDENT)
model = Sequential ([
    Flatten(input_shape=(28, 28)),
    Dense(128, activation='relu'),
    Dropout(0.2),
    Dense(10, activation='softmax')
])

model.summary()
# Out:
# Đinh Quốc Bảo - 6351071006
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten_1 (Flatten)             │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 128)            │       100,480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 10)             │         1,290 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 101,770 (397.54 KB)
#  Trainable params: 101,770 (397.54 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# # Câu f)

# %%
print(STUDENT)
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
# Out:
# Đinh Quốc Bảo - 6351071006

# %% [markdown]
# # Câu g)

# %%
print(NAME)
history = model.fit(train_images, train_labels,
                    epochs=5,
                    batch_size=32,
                    validation_data=(validation_images, validation_labels))
# Out:
# Đinh Quốc Bảo - 6351071006
# Epoch 1/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.8416 - loss: 0.5380 - val_accuracy: 0.9532 - val_loss: 0.1650
# Epoch 2/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 11s 8ms/step - accuracy: 0.9502 - loss: 0.1659 - val_accuracy: 0.9624 - val_loss: 0.1249
# Epoch 3/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9648 - loss: 0.1186 - val_accuracy: 0.9694 - val_loss: 0.1008
# Epoch 4/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9699 - loss: 0.0973 - val_accuracy: 0.9725 - val_loss: 0.0910
# Epoch 5/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 12s 8ms/step - accuracy: 0.9747 - loss: 0.0783 - val_accuracy: 0.9737 - val_loss: 0.0862

# %% [markdown]
# # Câu h)

# %%
import matplotlib.pyplot as plt

print(STUDENT)
# Vẽ biểu đồ accuracy
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

# Vẽ biểu đồ loss
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.show()
# Out:
# Đinh Quốc Bảo - 6351071006

# %% [markdown]
# # Câu i)

# %%
print(STUDENT)
predictions = model.predict(test_images)
predicted_labels = np.argmax(predictions, axis=1)
# Out:
# Đinh Quốc Bảo - 6351071006
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step

# %% [markdown]
# # Câu j)

# %%
from sklearn.metrics import accuracy_score

print(STUDENT)
accuracy = accuracy_score(test_labels, predicted_labels)
print(f'Accuracy trên tập test: {accuracy}')
# Out:
# Đinh Quốc Bảo - 6351071006
# Accuracy trên tập test: 0.9755

# %% [markdown]
# # Câu k)

# %%
from sklearn.metrics import classification_report

print(STUDENT)
print(classification_report(test_labels, predicted_labels))
# Out:
# Đinh Quốc Bảo - 6351071006
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98       980
#            1       0.99      0.99      0.99      1135
#            2       0.98      0.97      0.97      1032
#            3       0.98      0.98      0.98      1010
#            4       0.98      0.98      0.98       982
#            5       0.98      0.98      0.98       892
#            6       0.98      0.97      0.98       958
#            7       0.98      0.96      0.97      1028
#            8       0.96      0.97      0.96       974
#            9       0.97      0.96      0.96      1009
#
#     accuracy                           0.98     10000
#    macro avg       0.98      0.98      0.98     10000
# weighted avg       0.98      0.98      0.98     10000

# %% [markdown]
# # Câu l)

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

print(STUDENT)
cm = confusion_matrix(test_labels, predicted_labels)
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()
# Out:
# Đinh Quốc Bảo - 6351071006

# %% [markdown]
# # Câu m)

# %%
print(STUDENT)
for i in range(5):
    plt.imshow(test_images_original[i], cmap='gray')
    plt.title(f'Predicted: {predicted_labels[i]}, True: {test_labels[i]}')
    plt.show()
# Out:
# Đinh Quốc Bảo - 6351071006

# %% [markdown]
# # Câu n)

# %%
print(STUDENT)
misclassified_indices = np.where(predicted_labels != test_labels)[0]
for i in range(5):
    idx = misclassified_indices[i]
    plt.imshow(test_images_original[idx], cmap='gray')
    plt.title(f'Predicted: {predicted_labels[idx]}, True: {test_labels[idx]}')
    plt.show()
# Out:
# Đinh Quốc Bảo - 6351071006
